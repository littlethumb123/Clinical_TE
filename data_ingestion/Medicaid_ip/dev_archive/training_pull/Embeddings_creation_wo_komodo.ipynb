# %%
# !pip install h5py
# Out:
# Collecting h5py
#   Using cached h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from h5py) (1.26.4)
# Using cached h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Installing collected packages: h5py
# Successfully installed h5py-3.11.0

# %%
import random
random.seed(1234)
import pandas as pd
import numpy as np
import gc
gc.collect()
from sklearn.model_selection import train_test_split
import os
import math
import torch
torch.manual_seed(123)
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer, TransformerDecoderLayer, TransformerDecoder
from joblib import Parallel, delayed
import multiprocessing
from io import open
import argparse
import time
import math
import torch.onnx
import h5py
import os 
import pickle
from multiprocessing import cpu_count, Pool
from datetime import datetime
from google.cloud import storage
import joblib
from io import BytesIO
import google.auth
from google.auth import impersonated_credentials
from datetime import datetime
import pytz

import warnings
warnings.filterwarnings("ignore")

# %%
input_table_name = 'anbc-hcb-dev.cm_medicaid_hcb_dev.a534354_IP_2024_o3_score_ending'  # change to yours

output_feature_table_name = 'anbc-hcb-dev.cm_medicaid_hcb_dev.a534354_IP_2024_'  # change to yours

number_of_parts_2_run = 25# of parts to break the input table to.  In case Vertex AI fails, you can restart from where it fails

# %%
from google.cloud import bigquery
client = bigquery.Client()

credentials, project= google.auth.default()
print('credentials:', credentials, ', project:', project)

api_client = bigquery.Client(credentials=credentials)

job_labels = {"costcenter": 13070, "owner": "palmere1_aetna_com"}
load_config = bigquery.LoadJobConfig(labels=job_labels)
# Out:
# credentials: <google.oauth2.credentials.Credentials object at 0x7fa105740f40> , project: anbc-hcb-dev

# %%
class TransformerModel(nn.Module):
    def __init__(self, nhead, nhid, nlayers, dropout=0.05):
        super(TransformerModel, self).__init__()
        self.embedding_cd = nn.Embedding(cd_cnt,embedding_size)
        self.embedding_cd.weight.requires_grad = True
        self.embedding_gender_cd = nn.Embedding(4,embedding_size)
        self.embedding_gender_cd.weight.requires_grad = True
        self.embedding_age_in_months = nn.Embedding(1440,embedding_size)  
        self.embedding_age_in_months.weight.requires_grad = True
        encoder_layers_cd = TransformerEncoderLayer(embedding_size, 4, embedding_size, 0)
        self.transformer_encoder_cd = TransformerEncoder(encoder_layers_cd, 1)        
        encoder_layers_dy = TransformerEncoderLayer(embedding_size, nhead, nhid, dropout)
        self.transformer_encoder_dy = TransformerEncoder(encoder_layers_dy, nlayers)
 
        self.mm = nn.GELU()
        self.decoder_cd = nn.Linear(embedding_size, target_cd_cnt)
        self.dropout = nn.Dropout(0.1)
        self.norm = nn.LayerNorm(embedding_size)
        self.init_weights()
 
    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask
 
    def init_weights(self):
        initrange = 0.1
        nn.init.zeros_(self.decoder_cd.weight)
        nn.init.uniform_(self.decoder_cd.weight, -initrange, initrange)       
    def forward(self, x):     
        gpu_batchsize = x.shape[0]
        age_in_months = x[:,:,0]
        gender_cd = x[:,:,1]
        gender_cd = self.embedding_gender_cd(gender_cd)
        age_in_months = self.embedding_age_in_months(age_in_months)
        cd = x[:,:,2:]
        cd = self.embedding_cd(cd)
        cd_res = cd.sum(-2)
        # print(cd_res.shape)
        cd = cd.reshape(gpu_batchsize*len_dy,len_cd,embedding_size)
        cd = torch.swapaxes(cd, 0, 1) 
        cd = self.transformer_encoder_cd(cd)
        cd = cd.permute(1,2,0)
        cd = nn.MaxPool1d(len_cd)(cd)
        cd = cd.reshape(gpu_batchsize,len_dy,embedding_size)
        # print(cd.shape)
        cd = cd_res+cd + gender_cd + age_in_months
        # print(cd.shape)
        cd = self.mm(cd)
        cd = self.norm(cd)
        cd = torch.swapaxes(cd, 0, 1)
 
        mth_mask = self._generate_square_subsequent_mask(len_dy).to(device)      
        cd = self.transformer_encoder_dy(cd, mth_mask)
        cd = torch.swapaxes(cd, 0, 1)
        cd = self.norm(cd)
        cd = self.dropout(cd)
 
        cd = self.decoder_cd(cd)
        cd = F.log_softmax(cd, dim=-1)
 
        return cd

# %%
def dataLoader(fileid):
    blob = storage.Client(credentials=google.auth.default()[0]).bucket(bucket_name).blob(fileid)
    data = BytesIO()
    blob.download_to_file(data)
    data=joblib.load(data)
    return data

# %%
def currentTime():
    newYorkTz = pytz.timezone("America/New_York") 
    timeInNewYork = datetime.now(newYorkTz)
    currentTimeInNewYork = timeInNewYork.strftime("%D %H:%M:%S")
    return currentTimeInNewYork
 
def conv_cd(ipt):
    ipt = ipt.split('*')
    ipt = ipt[:len_dy]
    ipt = ipt + (len_dy-len(ipt))*['']
    ipt = [dy.split(',') for dy in ipt]
    ipt = [[int(cd) if cd!='' else 0 for cd in dy] for dy in ipt]
    ipt = [dy + (len_cd-len(dy))*[0] for dy in ipt]
    return ipt
 
def conv_age_gender(ipt):
    ipt = ipt.split('*')
    ipt = ipt[:len_dy]
    ipt = [min(int(cd),1439) for cd in ipt]
    ipt = ipt + (len_dy-len(ipt))*[0]
    return ipt
 
def conv_dy(x):
    x = x.split('*')
    x = x[:len_dy]
    x = [int(cd) for cd in x]
    return x

# %%
def prepare_tensor(batch):
    age_in_months = [conv_age_gender(ipt) for ipt in batch['age_in_months'].tolist()]
    age_in_months = torch.tensor(age_in_months).to(device)
    age_in_months = age_in_months.reshape(batch_size,len_dy,1)
    gender_cd = [conv_age_gender(ipt) for ipt in batch['gender_cd'].tolist()]
    gender_cd = torch.tensor(gender_cd).to(device)
    gender_cd = gender_cd.reshape(batch_size,len_dy,1)    
    cd = [conv_cd(ipt) for ipt in batch['cd'].tolist()]
    cd = torch.tensor(cd).to(device)
    x = torch.cat([age_in_months,gender_cd,cd],dim=-1)
 
    dt_cnt = batch['dt_cnt'].tolist()
 
    return dt_cnt,x
def train(data):
    model.train()
    nbatch = int(data.shape[0]/batch_size)
    for i in range(nbatch):
        if i%1000 == 0:
            print('batch',i,currentTime())
        optimizer.zero_grad()
        batch = data.iloc[i*batch_size:i*batch_size+batch_size,:]
        dt_cnt,x,y = prepare_tensor(batch)
        opt = model(x)
        opt = opt.reshape(batch_size*len_dy,target_cd_cnt)
        y = [item for sublist in y for item in sublist]
        opt = torch.cat([opt[len_dy*i:len_dy*i+dt_cnt[i],:] for i in range(batch_size)],dim=0)
        y = torch.tensor(y).to(device)
        loss = criterion(opt, y)        
        loss.backward()
        optimizer.step()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.25)
        for p in model.parameters():
            p.data.add_(p.grad, alpha=-optimizer.param_groups[0]['lr'])
 
        del batch,x,y,opt,loss
        gc.collect()
        torch.cuda.empty_cache()

# %%
def score(data,filename):
    model.eval()
    activation = {}
    def get_activation(name):
        def hook(model, input, output):
            activation[name] = output.detach()
        return hook
 
    model.transformer_encoder_dy.register_forward_hook(get_activation('transformer_encoder_dy'))
 
    dsize = data.shape[0]
    nbatch = int(dsize/batch_size)
    if dsize-nbatch*batch_size>0:
        k = batch_size - (dsize-nbatch*batch_size) # fill some records to build last trunk; these will be deleted in the end
        data = pd.concat([data,data.head(k)])
    data = data.reset_index(drop=True)
    nbatch = int(data.shape[0]/batch_size)
    ys = []
    for i in range(nbatch):
        batch = data.iloc[i*batch_size:i*batch_size+batch_size,:]
        dt_cnt,x = prepare_tensor(batch)
        opts = model(x)
        intermedia_output = activation['transformer_encoder_dy']       
        intermedia_output = [intermedia_output[dt_cnt[i],i,:].reshape(1,-1) for i in range(batch_size)]
        intermedia_output = torch.cat(intermedia_output)           
        ys.append(intermedia_output)
    ys = torch.cat(ys).cpu().numpy()
    ys = pd.DataFrame(ys,columns = ['emb'+str(i) for i in range(embedding_size)])
    ys[entity_id] = data[entity_id]
    ys = ys.head(dsize)
    blob = storage.Client(credentials=google.auth.default()[0]).bucket(bucket_name).blob(filename)
    with blob.open("wb", ignore_flush=True) as f:
        joblib.dump(ys, f)

# %%
def score_file(input_tbl, output_tbl, number_of_parts):
    #filename = os.path.join(data_path,ipt_name)
 
    #data = dataLoader(filename)
    
    sql = """
        select *
        from """ + input_tbl + """
        WHERE 1=1
        order by individual_id
    """
    data_all = client.query(sql).to_dataframe()  
    
    part_size = int(np.ceil(data_all.shape[0]/number_of_parts))
    
    print('all:', data_all.shape, ', part_size: ', part_size)
    
    for ith in range(number_of_parts):
        
        from_pos = ith * part_size 
        end_pos = (ith + 1) * part_size
        
        if ith == (number_of_parts - 1): end_pos = data_all.shape[0] +1
        
        data = data_all.iloc[from_pos : end_pos]

        print('after reading:', currentTime())

        print('input from:', from_pos, ' to:', end_pos)

        data['dt_cnt'] = data['dt_cnt'] - 1

        trunksize = batch_size*10

        ntrunks = int(data.shape[0]/trunksize) + 1

        for trunk_id in range(ntrunks):
            trunkdata = data.iloc[trunk_id*trunksize:(trunk_id+1)*trunksize,]
            trunkid = os.path.join(data_path,'trunk'+str(trunk_id)+'.p')
            score(trunkdata,trunkid)
            print(ith, ', scoring trunk_id:', trunk_id, ' of ', ntrunks)

        data2 = []
        for trunk_id in range(ntrunks):  
            trunkid = os.path.join(data_path,'trunk'+str(trunk_id)+'.p')
            data2.append(dataLoader(trunkid))
            print(ith, ', saving trunk_id:', trunk_id, ' of ', ntrunks)

        data2 = pd.concat(data2)
        
        print('after embedding:', currentTime())
        print(data2.shape)

        output_part = output_tbl + '_part_' + str(ith)
        
        api_client.delete_table(output_part + '_tmp', not_found_ok=True)

        load_job = api_client.load_table_from_dataframe(
            dataframe = data2,
            destination = output_part + '_tmp',
            job_config = load_config,
        )

        print(load_job.result())

        sql = """
            select count(1) as cnt
            from """ + output_part + '_tmp'

        cnt = client.query(sql).to_dataframe()  

        print('after:', cnt, 'output table name:', output_part + '_tmp')
        #for trunk_id in range(ntrunks):  
        #    trunkid = os.path.join(data_path,'trunk'+str(trunk_id)+'.p')
        #    blob = storage.Client(credentials=google.auth.default()[0]).bucket(bucket_name).blob(trunkid)
        #    blob.delete()

# %%
# %%time
print('program start:', currentTime())

bucket_name = "clin-analytics-data-hcb-dev"
# data_source = 'a321276/TransformerV9/Data/a321276_o2_'
model_path = 'a534354/TransformerV10/Model'
entity_id = 'individual_id'

# maybe further tuning the machine!!!!, 

batch_size = 16  #512, Jane changed to run on t4!!!
embedding_size = 256
minimum_mth_training = 6   #filter out data points which short month length
len_dy = 200 # how many days in th seq
len_cd = 80 # within a day how many cds. 
nhead = 16 # heads of transformer - double transformer share same feature...
nhid = 512 # number of hidden of transformer - double transformer share same feature...
nlayers = 6 # number of layers of transformer - double transformer share same feature...
ndropout = 0.1 # dropout rate of transformer - double transformer share same feature...
cd_cnt = 98041 # numbr of codes used in embedding matrix
target_cd_cnt = 2 # numbr of target codes 
criterion = nn.NLLLoss()
parallel = True
device = torch.device("cuda:0") 
#device = torch.device("cuda") #Jane changed to run on t4!!!
 
 
blob = storage.Client(credentials=google.auth.default()[0]).bucket(bucket_name).blob(os.path.join(model_path,'bestModel_singlegpu'))
bestModel = BytesIO()
blob.download_to_file(bestModel)
bestModel=joblib.load(bestModel)  
model = TransformerModel(nhead, nhid, nlayers, 0)
model.load_state_dict(bestModel['model'])
model = model.to(device)
 
data_path = 'a321276/TransformerV10/Data'
#ipt_name = 'a321276_o3_score_ending0.p'
 
#opt_name = 'tmp.p'
#score_file(data_path,ipt_name,opt_name)

score_file(input_table_name, output_feature_table_name, number_of_parts_2_run)

print('end:', currentTime())
# Out:
# program start: 06/01/24 12:44:40
# all: (2773232, 5) , part_size:  110930
# after reading: 06/01/24 12:45:58
# input from: 0  to: 110930
# 0 , scoring trunk_id: 0  of  694
# 0 , scoring trunk_id: 1  of  694
# 0 , scoring trunk_id: 2  of  694
# 0 , scoring trunk_id: 3  of  694
# 0 , scoring trunk_id: 4  of  694
# 0 , scoring trunk_id: 5  of  694
# 0 , scoring trunk_id: 6  of  694
# 0 , scoring trunk_id: 7  of  694
# 0 , scoring trunk_id: 8  of  694
# 0 , scoring trunk_id: 9  of  694
# 0 , scoring trunk_id: 10  of  694
# 0 , scoring trunk_id: 11  of  694
# 0 , scoring trunk_id: 12  of  694
# 0 , scoring trunk_id: 13  of  694
# 0 , scoring trunk_id: 14  of  694
# 0 , scoring trunk_id: 15  of  694
# 0 , scoring trunk_id: 16  of  694
# 0 , scoring trunk_id: 17  of  694
# 0 , scoring trunk_id: 18  of  694
# 0 , scoring trunk_id: 19  of  694
# 0 , scoring trunk_id: 20  of  694
# 0 , scoring trunk_id: 21  of  694
# 0 , scoring trunk_id: 22  of  694
# 0 , scoring trunk_id: 23  of  694
# 0 , scoring trunk_id: 24  of  694
# 0 , scoring trunk_id: 25  of  694
# 0 , scoring trunk_id: 26  of  694
# 0 , scoring trunk_id: 27  of  694
# 0 , scoring trunk_id: 28  of  694
# 0 , scoring trunk_id: 29  of  694
# 0 , scoring trunk_id: 30  of  694
# 0 , scoring trunk_id: 31  of  694
# 0 , scoring trunk_id: 32  of  694
# 0 , scoring trunk_id: 33  of  694
# 0 , scoring trunk_id: 34  of  694
# 0 , scoring trunk_id: 35  of  694
# 0 , scoring trunk_id: 36  of  694
# 0 , scoring trunk_id: 37  of  694
# 0 , scoring trunk_id: 38  of  694
# 0 , scoring trunk_id: 39  of  694
# 0 , scoring trunk_id: 40  of  694
# 0 , scoring trunk_id: 41  of  694
# 0 , scoring trunk_id: 42  of  694
# 0 , scoring trunk_id: 43  of  694
# 0 , scoring trunk_id: 44  of  694
# 0 , scoring trunk_id: 45  of  694
# 0 , scoring trunk_id: 46  of  694
# 0 , scoring trunk_id: 47  of  694
# 0 , scoring trunk_id: 48  of  694
# 0 , scoring trunk_id: 49  of  694
# 0 , scoring trunk_id: 50  of  694
# 0 , scoring trunk_id: 51  of  694
# 0 , scoring trunk_id: 52  of  694
# 0 , scoring trunk_id: 53  of  694
# 0 , scoring trunk_id: 54  of  694
# 0 , scoring trunk_id: 55  of  694
# 0 , scoring trunk_id: 56  of  694
# 0 , scoring trunk_id: 57  of  694
# 0 , scoring trunk_id: 58  of  694
# 0 , scoring trunk_id: 59  of  694
# 0 , scoring trunk_id: 60  of  694
# 0 , scoring trunk_id: 61  of  694
# 0 , scoring trunk_id: 62  of  694
# 0 , scoring trunk_id: 63  of  694
# 0 , scoring trunk_id: 64  of  694
# 0 , scoring trunk_id: 65  of  694
# 0 , scoring trunk_id: 66  of  694
# 0 , scoring trunk_id: 67  of  694
# 0 , scoring trunk_id: 68  of  694
# 0 , scoring trunk_id: 69  of  694
# 0 , scoring trunk_id: 70  of  694
# 0 , scoring trunk_id: 71  of  694
# 0 , scoring trunk_id: 72  of  694
# 0 , scoring trunk_id: 73  of  694
# 0 , scoring trunk_id: 74  of  694
# 0 , scoring trunk_id: 75  of  694
# 0 , scoring trunk_id: 76  of  694
# 0 , scoring trunk_id: 77  of  694
# 0 , scoring trunk_id: 78  of  694
# 0 , scoring trunk_id: 79  of  694
# 0 , scoring trunk_id: 80  of  694
# 0 , scoring trunk_id: 81  of  694
# 0 , scoring trunk_id: 82  of  694
# 0 , scoring trunk_id: 83  of  694
# 0 , scoring trunk_id: 84  of  694
# 0 , scoring trunk_id: 85  of  694
# 0 , scoring trunk_id: 86  of  694
# 0 , scoring trunk_id: 87  of  694
# 0 , scoring trunk_id: 88  of  694
# 0 , scoring trunk_id: 89  of  694
# 0 , scoring trunk_id: 90  of  694
# 0 , scoring trunk_id: 91  of  694
# 0 , scoring trunk_id: 92  of  694
# 0 , scoring trunk_id: 93  of  694
# 0 , scoring trunk_id: 94  of  694
# 0 , scoring trunk_id: 95  of  694
# 0 , scoring trunk_id: 96  of  694
# 0 , scoring trunk_id: 97  of  694
# 0 , scoring trunk_id: 98  of  694
# 0 , scoring trunk_id: 99  of  694
# 0 , scoring trunk_id: 100  of  694
# 0 , scoring trunk_id: 101  of  694
# 0 , scoring trunk_id: 102  of  694
# 0 , scoring trunk_id: 103  of  694
# 0 , scoring trunk_id: 104  of  694
# 0 , scoring trunk_id: 105  of  694
# 0 , scoring trunk_id: 106  of  694
# 0 , scoring trunk_id: 107  of  694
# 0 , scoring trunk_id: 108  of  694
# 0 , scoring trunk_id: 109  of  694
# 0 , scoring trunk_id: 110  of  694
# 0 , scoring trunk_id: 111  of  694
# 0 , scoring trunk_id: 112  of  694
# 0 , scoring trunk_id: 113  of  694
# 0 , scoring trunk_id: 114  of  694
# 0 , scoring trunk_id: 115  of  694
# 0 , scoring trunk_id: 116  of  694
# 0 , scoring trunk_id: 117  of  694
# 0 , scoring trunk_id: 118  of  694
# 0 , scoring trunk_id: 119  of  694
# 0 , scoring trunk_id: 120  of  694
# 0 , scoring trunk_id: 121  of  694
# 0 , scoring trunk_id: 122  of  694
# 0 , scoring trunk_id: 123  of  694
# 0 , scoring trunk_id: 124  of  694
# 0 , scoring trunk_id: 125  of  694
# 0 , scoring trunk_id: 126  of  694
# 0 , scoring trunk_id: 127  of  694
# 0 , scoring trunk_id: 128  of  694
# 0 , scoring trunk_id: 129  of  694
# 0 , scoring trunk_id: 130  of  694
# 0 , scoring trunk_id: 131  of  694
# 0 , scoring trunk_id: 132  of  694
# 0 , scoring trunk_id: 133  of  694
# 0 , scoring trunk_id: 134  of  694
# 0 , scoring trunk_id: 135  of  694
# 0 , scoring trunk_id: 136  of  694
# 0 , scoring trunk_id: 137  of  694
# 0 , scoring trunk_id: 138  of  694
# 0 , scoring trunk_id: 139  of  694
# 0 , scoring trunk_id: 140  of  694
# 0 , scoring trunk_id: 141  of  694
# 0 , scoring trunk_id: 142  of  694
# 0 , scoring trunk_id: 143  of  694
# 0 , scoring trunk_id: 144  of  694
# 0 , scoring trunk_id: 145  of  694
# 0 , scoring trunk_id: 146  of  694
# 0 , scoring trunk_id: 147  of  694
# 0 , scoring trunk_id: 148  of  694
# 0 , scoring trunk_id: 149  of  694
# 0 , scoring trunk_id: 150  of  694
# 0 , scoring trunk_id: 151  of  694
# 0 , scoring trunk_id: 152  of  694
# 0 , scoring trunk_id: 153  of  694
# 0 , scoring trunk_id: 154  of  694
# 0 , scoring trunk_id: 155  of  694
# 0 , scoring trunk_id: 156  of  694
# 0 , scoring trunk_id: 157  of  694
# 0 , scoring trunk_id: 158  of  694
# 0 , scoring trunk_id: 159  of  694
# 0 , scoring trunk_id: 160  of  694
# 0 , scoring trunk_id: 161  of  694
# 0 , scoring trunk_id: 162  of  694
# 0 , scoring trunk_id: 163  of  694
# 0 , scoring trunk_id: 164  of  694
# 0 , scoring trunk_id: 165  of  694
# 0 , scoring trunk_id: 166  of  694
# 0 , scoring trunk_id: 167  of  694
# 0 , scoring trunk_id: 168  of  694
# 0 , scoring trunk_id: 169  of  694
# 0 , scoring trunk_id: 170  of  694
# 0 , scoring trunk_id: 171  of  694
# 0 , scoring trunk_id: 172  of  694
# 0 , scoring trunk_id: 173  of  694
# 0 , scoring trunk_id: 174  of  694
# 0 , scoring trunk_id: 175  of  694
# 0 , scoring trunk_id: 176  of  694
# 0 , scoring trunk_id: 177  of  694
# 0 , scoring trunk_id: 178  of  694
# 0 , scoring trunk_id: 179  of  694
# 0 , scoring trunk_id: 180  of  694
# 0 , scoring trunk_id: 181  of  694
# 0 , scoring trunk_id: 182  of  694
# 0 , scoring trunk_id: 183  of  694
# 0 , scoring trunk_id: 184  of  694
# 0 , scoring trunk_id: 185  of  694
# 0 , scoring trunk_id: 186  of  694
# 0 , scoring trunk_id: 187  of  694
# 0 , scoring trunk_id: 188  of  694
# 0 , scoring trunk_id: 189  of  694
# 0 , scoring trunk_id: 190  of  694
# 0 , scoring trunk_id: 191  of  694
# 0 , scoring trunk_id: 192  of  694
# 0 , scoring trunk_id: 193  of  694
# 0 , scoring trunk_id: 194  of  694
# 0 , scoring trunk_id: 195  of  694
# 0 , scoring trunk_id: 196  of  694
# 0 , scoring trunk_id: 197  of  694
# 0 , scoring trunk_id: 198  of  694
# 0 , scoring trunk_id: 199  of  694
# 0 , scoring trunk_id: 200  of  694
# 0 , scoring trunk_id: 201  of  694
# 0 , scoring trunk_id: 202  of  694
# 0 , scoring trunk_id: 203  of  694
# 0 , scoring trunk_id: 204  of  694
# 0 , scoring trunk_id: 205  of  694
# 0 , scoring trunk_id: 206  of  694
# 0 , scoring trunk_id: 207  of  694
# 0 , scoring trunk_id: 208  of  694
# 0 , scoring trunk_id: 209  of  694
# 0 , scoring trunk_id: 210  of  694
# 0 , scoring trunk_id: 211  of  694
# 0 , scoring trunk_id: 212  of  694
# 0 , scoring trunk_id: 213  of  694
# 0 , scoring trunk_id: 214  of  694
# 0 , scoring trunk_id: 215  of  694
# 0 , scoring trunk_id: 216  of  694
# 0 , scoring trunk_id: 217  of  694
# 0 , scoring trunk_id: 218  of  694
# 0 , scoring trunk_id: 219  of  694
# 0 , scoring trunk_id: 220  of  694
# 0 , scoring trunk_id: 221  of  694
# 0 , scoring trunk_id: 222  of  694
# 0 , scoring trunk_id: 223  of  694
# 0 , scoring trunk_id: 224  of  694
# 0 , scoring trunk_id: 225  of  694
# 0 , scoring trunk_id: 226  of  694
# 0 , scoring trunk_id: 227  of  694
# 0 , scoring trunk_id: 228  of  694
# 0 , scoring trunk_id: 229  of  694
# 0 , scoring trunk_id: 230  of  694
# 0 , scoring trunk_id: 231  of  694
# 0 , scoring trunk_id: 232  of  694
# 0 , scoring trunk_id: 233  of  694
# 0 , scoring trunk_id: 234  of  694
# 0 , scoring trunk_id: 235  of  694
# 0 , scoring trunk_id: 236  of  694
# 0 , scoring trunk_id: 237  of  694
# 0 , scoring trunk_id: 238  of  694
# 0 , scoring trunk_id: 239  of  694
# 0 , scoring trunk_id: 240  of  694
# 0 , scoring trunk_id: 241  of  694
# 0 , scoring trunk_id: 242  of  694
# 0 , scoring trunk_id: 243  of  694
# 0 , scoring trunk_id: 244  of  694
# 0 , scoring trunk_id: 245  of  694
# 0 , scoring trunk_id: 246  of  694
# 0 , scoring trunk_id: 247  of  694
# 0 , scoring trunk_id: 248  of  694
# 0 , scoring trunk_id: 249  of  694
# 0 , scoring trunk_id: 250  of  694
# 0 , scoring trunk_id: 251  of  694
# 0 , scoring trunk_id: 252  of  694
# 0 , scoring trunk_id: 253  of  694
# 0 , scoring trunk_id: 254  of  694
# 0 , scoring trunk_id: 255  of  694
# 0 , scoring trunk_id: 256  of  694
# 0 , scoring trunk_id: 257  of  694
# 0 , scoring trunk_id: 258  of  694
# 0 , scoring trunk_id: 259  of  694
# 0 , scoring trunk_id: 260  of  694
# 0 , scoring trunk_id: 261  of  694
# 0 , scoring trunk_id: 262  of  694
# 0 , scoring trunk_id: 263  of  694
# 0 , scoring trunk_id: 264  of  694
# 0 , scoring trunk_id: 265  of  694
# 0 , scoring trunk_id: 266  of  694
# 0 , scoring trunk_id: 267  of  694
# 0 , scoring trunk_id: 268  of  694
# 0 , scoring trunk_id: 269  of  694
# 0 , scoring trunk_id: 270  of  694
# 0 , scoring trunk_id: 271  of  694
# 0 , scoring trunk_id: 272  of  694
# 0 , scoring trunk_id: 273  of  694
# 0 , scoring trunk_id: 274  of  694
# 0 , scoring trunk_id: 275  of  694
# 0 , scoring trunk_id: 276  of  694
# 0 , scoring trunk_id: 277  of  694
# 0 , scoring trunk_id: 278  of  694
# 0 , scoring trunk_id: 279  of  694
# 0 , scoring trunk_id: 280  of  694
# 0 , scoring trunk_id: 281  of  694
# 0 , scoring trunk_id: 282  of  694
# 0 , scoring trunk_id: 283  of  694
# 0 , scoring trunk_id: 284  of  694
# 0 , scoring trunk_id: 285  of  694
# 0 , scoring trunk_id: 286  of  694
# 0 , scoring trunk_id: 287  of  694
# 0 , scoring trunk_id: 288  of  694
# 0 , scoring trunk_id: 289  of  694
# 0 , scoring trunk_id: 290  of  694
# 0 , scoring trunk_id: 291  of  694
# 0 , scoring trunk_id: 292  of  694
# 0 , scoring trunk_id: 293  of  694
# 0 , scoring trunk_id: 294  of  694
# 0 , scoring trunk_id: 295  of  694
# 0 , scoring trunk_id: 296  of  694
# 0 , scoring trunk_id: 297  of  694
# 0 , scoring trunk_id: 298  of  694
# 0 , scoring trunk_id: 299  of  694
# 0 , scoring trunk_id: 300  of  694
# 0 , scoring trunk_id: 301  of  694
# 0 , scoring trunk_id: 302  of  694
# 0 , scoring trunk_id: 303  of  694
# 0 , scoring trunk_id: 304  of  694
# 0 , scoring trunk_id: 305  of  694
# 0 , scoring trunk_id: 306  of  694
# 0 , scoring trunk_id: 307  of  694
# 0 , scoring trunk_id: 308  of  694
# 0 , scoring trunk_id: 309  of  694
# 0 , scoring trunk_id: 310  of  694
# 0 , scoring trunk_id: 311  of  694
# 0 , scoring trunk_id: 312  of  694
# 0 , scoring trunk_id: 313  of  694
# 0 , scoring trunk_id: 314  of  694
# 0 , scoring trunk_id: 315  of  694
# 0 , scoring trunk_id: 316  of  694
# 0 , scoring trunk_id: 317  of  694
# 0 , scoring trunk_id: 318  of  694
# 0 , scoring trunk_id: 319  of  694
# 0 , scoring trunk_id: 320  of  694
# 0 , scoring trunk_id: 321  of  694
# 0 , scoring trunk_id: 322  of  694
# 0 , scoring trunk_id: 323  of  694
# 0 , scoring trunk_id: 324  of  694
# 0 , scoring trunk_id: 325  of  694
# 0 , scoring trunk_id: 326  of  694
# 0 , scoring trunk_id: 327  of  694
# 0 , scoring trunk_id: 328  of  694
# 0 , scoring trunk_id: 329  of  694
# 0 , scoring trunk_id: 330  of  694
# 0 , scoring trunk_id: 331  of  694
# 0 , scoring trunk_id: 332  of  694
# 0 , scoring trunk_id: 333  of  694
# 0 , scoring trunk_id: 334  of  694
# 0 , scoring trunk_id: 335  of  694
# 0 , scoring trunk_id: 336  of  694
# 0 , scoring trunk_id: 337  of  694
# 0 , scoring trunk_id: 338  of  694
# 0 , scoring trunk_id: 339  of  694
# 0 , scoring trunk_id: 340  of  694
# 0 , scoring trunk_id: 341  of  694
# 0 , scoring trunk_id: 342  of  694
# 0 , scoring trunk_id: 343  of  694
# 0 , scoring trunk_id: 344  of  694
# 0 , scoring trunk_id: 345  of  694
# 0 , scoring trunk_id: 346  of  694
# 0 , scoring trunk_id: 347  of  694
# 0 , scoring trunk_id: 348  of  694
# 0 , scoring trunk_id: 349  of  694
# 0 , scoring trunk_id: 350  of  694
# 0 , scoring trunk_id: 351  of  694
# 0 , scoring trunk_id: 352  of  694
# 0 , scoring trunk_id: 353  of  694
# 0 , scoring trunk_id: 354  of  694
# 0 , scoring trunk_id: 355  of  694
# 0 , scoring trunk_id: 356  of  694
# 0 , scoring trunk_id: 357  of  694
# 0 , scoring trunk_id: 358  of  694
# 0 , scoring trunk_id: 359  of  694
# 0 , scoring trunk_id: 360  of  694
# 0 , scoring trunk_id: 361  of  694
# 0 , scoring trunk_id: 362  of  694
# 0 , scoring trunk_id: 363  of  694
# 0 , scoring trunk_id: 364  of  694
# 0 , scoring trunk_id: 365  of  694
# 0 , scoring trunk_id: 366  of  694
# 0 , scoring trunk_id: 367  of  694
# 0 , scoring trunk_id: 368  of  694
# 0 , scoring trunk_id: 369  of  694
# 0 , scoring trunk_id: 370  of  694
# 0 , scoring trunk_id: 371  of  694
# 0 , scoring trunk_id: 372  of  694
# 0 , scoring trunk_id: 373  of  694
# 0 , scoring trunk_id: 374  of  694
# 0 , scoring trunk_id: 375  of  694
# 0 , scoring trunk_id: 376  of  694
# 0 , scoring trunk_id: 377  of  694
# 0 , scoring trunk_id: 378  of  694
# 0 , scoring trunk_id: 379  of  694
# 0 , scoring trunk_id: 380  of  694
# 0 , scoring trunk_id: 381  of  694
# 0 , scoring trunk_id: 382  of  694
# 0 , scoring trunk_id: 383  of  694
# 0 , scoring trunk_id: 384  of  694
# 0 , scoring trunk_id: 385  of  694
# 0 , scoring trunk_id: 386  of  694
# 0 , scoring trunk_id: 387  of  694
# 0 , scoring trunk_id: 388  of  694
# 0 , scoring trunk_id: 389  of  694
# 0 , scoring trunk_id: 390  of  694
# 0 , scoring trunk_id: 391  of  694
# 0 , scoring trunk_id: 392  of  694
# 0 , scoring trunk_id: 393  of  694
# 0 , scoring trunk_id: 394  of  694
# 0 , scoring trunk_id: 395  of  694
# 0 , scoring trunk_id: 396  of  694
# 0 , scoring trunk_id: 397  of  694
# 0 , scoring trunk_id: 398  of  694
# 0 , scoring trunk_id: 399  of  694
# 0 , scoring trunk_id: 400  of  694
# 0 , scoring trunk_id: 401  of  694
# 0 , scoring trunk_id: 402  of  694
# 0 , scoring trunk_id: 403  of  694
# 0 , scoring trunk_id: 404  of  694
# 0 , scoring trunk_id: 405  of  694
# 0 , scoring trunk_id: 406  of  694
# 0 , scoring trunk_id: 407  of  694
# 0 , scoring trunk_id: 408  of  694
# 0 , scoring trunk_id: 409  of  694
# 0 , scoring trunk_id: 410  of  694
# 0 , scoring trunk_id: 411  of  694
# 0 , scoring trunk_id: 412  of  694
# 0 , scoring trunk_id: 413  of  694
# 0 , scoring trunk_id: 414  of  694
# 0 , scoring trunk_id: 415  of  694
# 0 , scoring trunk_id: 416  of  694
# 0 , scoring trunk_id: 417  of  694
# 0 , scoring trunk_id: 418  of  694
# 0 , scoring trunk_id: 419  of  694
# 0 , scoring trunk_id: 420  of  694
# 0 , scoring trunk_id: 421  of  694
# 0 , scoring trunk_id: 422  of  694
# 0 , scoring trunk_id: 423  of  694
# 0 , scoring trunk_id: 424  of  694
# 0 , scoring trunk_id: 425  of  694
# 0 , scoring trunk_id: 426  of  694
# 0 , scoring trunk_id: 427  of  694
# 0 , scoring trunk_id: 428  of  694
# 0 , scoring trunk_id: 429  of  694
# 0 , scoring trunk_id: 430  of  694
# 0 , scoring trunk_id: 431  of  694
# 0 , scoring trunk_id: 432  of  694
# 0 , scoring trunk_id: 433  of  694
# 0 , scoring trunk_id: 434  of  694
# 0 , scoring trunk_id: 435  of  694
# 0 , scoring trunk_id: 436  of  694
# 0 , scoring trunk_id: 437  of  694
# 0 , scoring trunk_id: 438  of  694
# 0 , scoring trunk_id: 439  of  694
# 0 , scoring trunk_id: 440  of  694
# 0 , scoring trunk_id: 441  of  694
# 0 , scoring trunk_id: 442  of  694
# 0 , scoring trunk_id: 443  of  694
# 0 , scoring trunk_id: 444  of  694
# 0 , scoring trunk_id: 445  of  694
# 0 , scoring trunk_id: 446  of  694
# 0 , scoring trunk_id: 447  of  694
# 0 , scoring trunk_id: 448  of  694
# 0 , scoring trunk_id: 449  of  694
# 0 , scoring trunk_id: 450  of  694
# 0 , scoring trunk_id: 451  of  694
# 0 , scoring trunk_id: 452  of  694
# 0 , scoring trunk_id: 453  of  694
# 0 , scoring trunk_id: 454  of  694
# 0 , scoring trunk_id: 455  of  694
# 0 , scoring trunk_id: 456  of  694
# 0 , scoring trunk_id: 457  of  694
# 0 , scoring trunk_id: 458  of  694
# 0 , scoring trunk_id: 459  of  694
# 0 , scoring trunk_id: 460  of  694
# 0 , scoring trunk_id: 461  of  694
# 0 , scoring trunk_id: 462  of  694
# 0 , scoring trunk_id: 463  of  694
# 0 , scoring trunk_id: 464  of  694
# 0 , scoring trunk_id: 465  of  694
# 0 , scoring trunk_id: 466  of  694
# 0 , scoring trunk_id: 467  of  694
# 0 , scoring trunk_id: 468  of  694
# 0 , scoring trunk_id: 469  of  694
# 0 , scoring trunk_id: 470  of  694
# 0 , scoring trunk_id: 471  of  694
# 0 , scoring trunk_id: 472  of  694
# 0 , scoring trunk_id: 473  of  694
# 0 , scoring trunk_id: 474  of  694
# 0 , scoring trunk_id: 475  of  694
# 0 , scoring trunk_id: 476  of  694
# 0 , scoring trunk_id: 477  of  694
# 0 , scoring trunk_id: 478  of  694
# 0 , scoring trunk_id: 479  of  694
# 0 , scoring trunk_id: 480  of  694
# 0 , scoring trunk_id: 481  of  694
# 0 , scoring trunk_id: 482  of  694
# 0 , scoring trunk_id: 483  of  694
# 0 , scoring trunk_id: 484  of  694
# 0 , scoring trunk_id: 485  of  694
# 0 , scoring trunk_id: 486  of  694
# 0 , scoring trunk_id: 487  of  694
# 0 , scoring trunk_id: 488  of  694
# 0 , scoring trunk_id: 489  of  694
# 0 , scoring trunk_id: 490  of  694
# 0 , scoring trunk_id: 491  of  694
# 0 , scoring trunk_id: 492  of  694
# 0 , scoring trunk_id: 493  of  694
# 0 , scoring trunk_id: 494  of  694
# 0 , scoring trunk_id: 495  of  694
# 0 , scoring trunk_id: 496  of  694
# 0 , scoring trunk_id: 497  of  694
# 0 , scoring trunk_id: 498  of  694
# 0 , scoring trunk_id: 499  of  694
# 0 , scoring trunk_id: 500  of  694
# 0 , scoring trunk_id: 501  of  694
# 0 , scoring trunk_id: 502  of  694
# 0 , scoring trunk_id: 503  of  694
# 0 , scoring trunk_id: 504  of  694
# 0 , scoring trunk_id: 505  of  694
# 0 , scoring trunk_id: 506  of  694
# 0 , scoring trunk_id: 507  of  694
# 0 , scoring trunk_id: 508  of  694
# 0 , scoring trunk_id: 509  of  694
# 0 , scoring trunk_id: 510  of  694
# 0 , scoring trunk_id: 511  of  694
# 0 , scoring trunk_id: 512  of  694
# 0 , scoring trunk_id: 513  of  694
# 0 , scoring trunk_id: 514  of  694
# 0 , scoring trunk_id: 515  of  694
# 0 , scoring trunk_id: 516  of  694
# 0 , scoring trunk_id: 517  of  694
# 0 , scoring trunk_id: 518  of  694
# 0 , scoring trunk_id: 519  of  694
# 0 , scoring trunk_id: 520  of  694
# 0 , scoring trunk_id: 521  of  694
# 0 , scoring trunk_id: 522  of  694
# 0 , scoring trunk_id: 523  of  694
# 0 , scoring trunk_id: 524  of  694
# 0 , scoring trunk_id: 525  of  694
# 0 , scoring trunk_id: 526  of  694
# 0 , scoring trunk_id: 527  of  694
# 0 , scoring trunk_id: 528  of  694
# 0 , scoring trunk_id: 529  of  694
# 0 , scoring trunk_id: 530  of  694
# 0 , scoring trunk_id: 531  of  694
# 0 , scoring trunk_id: 532  of  694
# 0 , scoring trunk_id: 533  of  694
# 0 , scoring trunk_id: 534  of  694
# 0 , scoring trunk_id: 535  of  694
# 0 , scoring trunk_id: 536  of  694
# 0 , scoring trunk_id: 537  of  694
# 0 , scoring trunk_id: 538  of  694
# 0 , scoring trunk_id: 539  of  694
# 0 , scoring trunk_id: 540  of  694
# 0 , scoring trunk_id: 541  of  694
# 0 , scoring trunk_id: 542  of  694
# 0 , scoring trunk_id: 543  of  694
# 0 , scoring trunk_id: 544  of  694
# 0 , scoring trunk_id: 545  of  694
# 0 , scoring trunk_id: 546  of  694
# 0 , scoring trunk_id: 547  of  694
# 0 , scoring trunk_id: 548  of  694
# 0 , scoring trunk_id: 549  of  694
# 0 , scoring trunk_id: 550  of  694
# 0 , scoring trunk_id: 551  of  694
# 0 , scoring trunk_id: 552  of  694
# 0 , scoring trunk_id: 553  of  694
# 0 , scoring trunk_id: 554  of  694
# 0 , scoring trunk_id: 555  of  694
# 0 , scoring trunk_id: 556  of  694
# 0 , scoring trunk_id: 557  of  694
# 0 , scoring trunk_id: 558  of  694
# 0 , scoring trunk_id: 559  of  694
# 0 , scoring trunk_id: 560  of  694
# 0 , scoring trunk_id: 561  of  694
# 0 , scoring trunk_id: 562  of  694
# 0 , scoring trunk_id: 563  of  694
# 0 , scoring trunk_id: 564  of  694
# 0 , scoring trunk_id: 565  of  694
# 0 , scoring trunk_id: 566  of  694
# 0 , scoring trunk_id: 567  of  694
# 0 , scoring trunk_id: 568  of  694
# 0 , scoring trunk_id: 569  of  694
# 0 , scoring trunk_id: 570  of  694
# 0 , scoring trunk_id: 571  of  694
# 0 , scoring trunk_id: 572  of  694
# 0 , scoring trunk_id: 573  of  694
# 0 , scoring trunk_id: 574  of  694
# 0 , scoring trunk_id: 575  of  694
# 0 , scoring trunk_id: 576  of  694
# 0 , scoring trunk_id: 577  of  694
# 0 , scoring trunk_id: 578  of  694
# 0 , scoring trunk_id: 579  of  694
# 0 , scoring trunk_id: 580  of  694
# 0 , scoring trunk_id: 581  of  694
# 0 , scoring trunk_id: 582  of  694
# 0 , scoring trunk_id: 583  of  694
# 0 , scoring trunk_id: 584  of  694
# 0 , scoring trunk_id: 585  of  694
# 0 , scoring trunk_id: 586  of  694
# 0 , scoring trunk_id: 587  of  694
# 0 , scoring trunk_id: 588  of  694
# 0 , scoring trunk_id: 589  of  694
# 0 , scoring trunk_id: 590  of  694
# 0 , scoring trunk_id: 591  of  694
# 0 , scoring trunk_id: 592  of  694
# 0 , scoring trunk_id: 593  of  694
# 0 , scoring trunk_id: 594  of  694
# 0 , scoring trunk_id: 595  of  694
# 0 , scoring trunk_id: 596  of  694
# 0 , scoring trunk_id: 597  of  694
# 0 , scoring trunk_id: 598  of  694
# 0 , scoring trunk_id: 599  of  694
# 0 , scoring trunk_id: 600  of  694
# 0 , scoring trunk_id: 601  of  694
# 0 , scoring trunk_id: 602  of  694
# 0 , scoring trunk_id: 603  of  694
# 0 , scoring trunk_id: 604  of  694
# 0 , scoring trunk_id: 605  of  694
# 0 , scoring trunk_id: 606  of  694
# 0 , scoring trunk_id: 607  of  694
# 0 , scoring trunk_id: 608  of  694
# 0 , scoring trunk_id: 609  of  694
# 0 , scoring trunk_id: 610  of  694
# 0 , scoring trunk_id: 611  of  694
# 0 , scoring trunk_id: 612  of  694
# 0 , scoring trunk_id: 613  of  694
# 0 , scoring trunk_id: 614  of  694
# 0 , scoring trunk_id: 615  of  694
# 0 , scoring trunk_id: 616  of  694
# 0 , scoring trunk_id: 617  of  694
# 0 , scoring trunk_id: 618  of  694
# 0 , scoring trunk_id: 619  of  694
# 0 , scoring trunk_id: 620  of  694
# 0 , scoring trunk_id: 621  of  694
# 0 , scoring trunk_id: 622  of  694
# 0 , scoring trunk_id: 623  of  694
# 0 , scoring trunk_id: 624  of  694
# 0 , scoring trunk_id: 625  of  694
# 0 , scoring trunk_id: 626  of  694
# 0 , scoring trunk_id: 627  of  694
# 0 , scoring trunk_id: 628  of  694
# 0 , scoring trunk_id: 629  of  694
# 0 , scoring trunk_id: 630  of  694
# 0 , scoring trunk_id: 631  of  694
# 0 , scoring trunk_id: 632  of  694
# 0 , scoring trunk_id: 633  of  694
# 0 , scoring trunk_id: 634  of  694
# 0 , scoring trunk_id: 635  of  694
# 0 , scoring trunk_id: 636  of  694
# 0 , scoring trunk_id: 637  of  694
# 0 , scoring trunk_id: 638  of  694
# 0 , scoring trunk_id: 639  of  694
# 0 , scoring trunk_id: 640  of  694
# 0 , scoring trunk_id: 641  of  694
# 0 , scoring trunk_id: 642  of  694
# 0 , scoring trunk_id: 643  of  694
# 0 , scoring trunk_id: 644  of  694
# 0 , scoring trunk_id: 645  of  694
# 0 , scoring trunk_id: 646  of  694
# 0 , scoring trunk_id: 647  of  694
# 0 , scoring trunk_id: 648  of  694
# 0 , scoring trunk_id: 649  of  694
# 0 , scoring trunk_id: 650  of  694
# 0 , scoring trunk_id: 651  of  694
# 0 , scoring trunk_id: 652  of  694
# 0 , scoring trunk_id: 653  of  694
# 0 , scoring trunk_id: 654  of  694
# 0 , scoring trunk_id: 655  of  694
# 0 , scoring trunk_id: 656  of  694
# 0 , scoring trunk_id: 657  of  694
# 0 , scoring trunk_id: 658  of  694
# 0 , scoring trunk_id: 659  of  694
# 0 , scoring trunk_id: 660  of  694
# 0 , scoring trunk_id: 661  of  694
# 0 , scoring trunk_id: 662  of  694
# 0 , scoring trunk_id: 663  of  694
# 0 , scoring trunk_id: 664  of  694
# 0 , scoring trunk_id: 665  of  694
# 0 , scoring trunk_id: 666  of  694
# 0 , scoring trunk_id: 667  of  694
# 0 , scoring trunk_id: 668  of  694
# 0 , scoring trunk_id: 669  of  694
# 0 , scoring trunk_id: 670  of  694
# 0 , scoring trunk_id: 671  of  694
# 0 , scoring trunk_id: 672  of  694
# 0 , scoring trunk_id: 673  of  694
# 0 , scoring trunk_id: 674  of  694
# 0 , scoring trunk_id: 675  of  694
# 0 , scoring trunk_id: 676  of  694
# 0 , scoring trunk_id: 677  of  694
# 0 , scoring trunk_id: 678  of  694
# 0 , scoring trunk_id: 679  of  694
# 0 , scoring trunk_id: 680  of  694
# 0 , scoring trunk_id: 681  of  694
# 0 , scoring trunk_id: 682  of  694
# 0 , scoring trunk_id: 683  of  694
# 0 , scoring trunk_id: 684  of  694
# 0 , scoring trunk_id: 685  of  694
# 0 , scoring trunk_id: 686  of  694
# 0 , scoring trunk_id: 687  of  694
# 0 , scoring trunk_id: 688  of  694
# 0 , scoring trunk_id: 689  of  694
# 0 , scoring trunk_id: 690  of  694
# 0 , scoring trunk_id: 691  of  694
# 0 , scoring trunk_id: 692  of  694
# 0 , scoring trunk_id: 693  of  694
# 0 , saving trunk_id: 0  of  694
# 0 , saving trunk_id: 1  of  694
# 0 , saving trunk_id: 623  of  694
# 0 , saving trunk_id: 624  of  694
# 0 , saving trunk_id: 625  of  694
# 0 , saving trunk_id: 626  of  694
# 0 , saving trunk_id: 627  of  694
# 0 , saving trunk_id: 628  of  694
# 0 , saving trunk_id: 629  of  694
# 0 , saving trunk_id: 630  of  694
# 0 , saving trunk_id: 631  of  694
# 0 , saving trunk_id: 632  of  694
# 0 , saving trunk_id: 633  of  694
# 0 , saving trunk_id: 634  of  694
# 0 , saving trunk_id: 635  of  694
# 0 , saving trunk_id: 636  of  694
# 0 , saving trunk_id: 637  of  694
# 0 , saving trunk_id: 638  of  694
# 0 , saving trunk_id: 639  of  694
# 0 , saving trunk_id: 640  of  694
# 0 , saving trunk_id: 641  of  694
# 0 , saving trunk_id: 642  of  694
# 0 , saving trunk_id: 643  of  694
# 0 , saving trunk_id: 644  of  694
# 0 , saving trunk_id: 645  of  694
# 0 , saving trunk_id: 646  of  694
# 0 , saving trunk_id: 647  of  694
# 0 , saving trunk_id: 648  of  694
# 0 , saving trunk_id: 649  of  694
# 0 , saving trunk_id: 650  of  694
# 0 , saving trunk_id: 651  of  694
# 0 , saving trunk_id: 652  of  694
# 0 , saving trunk_id: 653  of  694
# 0 , saving trunk_id: 654  of  694
# 0 , saving trunk_id: 655  of  694
# 0 , saving trunk_id: 656  of  694
# 0 , saving trunk_id: 657  of  694
# 0 , saving trunk_id: 658  of  694
# 0 , saving trunk_id: 659  of  694
# 0 , saving trunk_id: 660  of  694
# 0 , saving trunk_id: 661  of  694
# 0 , saving trunk_id: 662  of  694
# 0 , saving trunk_id: 663  of  694
# 0 , saving trunk_id: 664  of  694
# 0 , saving trunk_id: 665  of  694
# 0 , saving trunk_id: 666  of  694
# 0 , saving trunk_id: 667  of  694
# 0 , saving trunk_id: 668  of  694
# 0 , saving trunk_id: 669  of  694
# 0 , saving trunk_id: 670  of  694
# 0 , saving trunk_id: 671  of  694
# 0 , saving trunk_id: 672  of  694
# 0 , saving trunk_id: 673  of  694
# 0 , saving trunk_id: 674  of  694
# 0 , saving trunk_id: 675  of  694
# 0 , saving trunk_id: 676  of  694
# 0 , saving trunk_id: 677  of  694
# 0 , saving trunk_id: 678  of  694
# 0 , saving trunk_id: 679  of  694
# 0 , saving trunk_id: 680  of  694
# 0 , saving trunk_id: 681  of  694
# 0 , saving trunk_id: 682  of  694
# 0 , saving trunk_id: 683  of  694
# 0 , saving trunk_id: 684  of  694
# 0 , saving trunk_id: 685  of  694
# 0 , saving trunk_id: 686  of  694
# 0 , saving trunk_id: 687  of  694
# 0 , saving trunk_id: 688  of  694
# 0 , saving trunk_id: 689  of  694
# 0 , saving trunk_id: 690  of  694
# 0 , saving trunk_id: 691  of  694
# 0 , saving trunk_id: 692  of  694
# 0 , saving trunk_id: 693  of  694
# after embedding: 06/01/24 13:30:32
# (110930, 257)
# LoadJob<project=anbc-hcb-dev, location=US, id=f7ba4588-98dd-4763-985a-30ca0a1ae9b4>
# after:       cnt
# ...
# 15 , scoring trunk_id: 42  of  694
# 15 , scoring trunk_id: 43  of  694
# 15 , scoring trunk_id: 44  of  694
# 15 , scoring trunk_id: 45  of  694
# 15 , scoring trunk_id: 46  of  694
# 15 , scoring trunk_id: 47  of  694
# 15 , scoring trunk_id: 48  of  694
# 15 , scoring trunk_id: 49  of  694
# 15 , scoring trunk_id: 50  of  694
# 15 , scoring trunk_id: 51  of  694
# 15 , scoring trunk_id: 52  of  694
# 15 , scoring trunk_id: 53  of  694
# 15 , scoring trunk_id: 54  of  694
# 15 , scoring trunk_id: 55  of  694
# 15 , scoring trunk_id: 56  of  694
# 15 , scoring trunk_id: 57  of  694
# 15 , scoring trunk_id: 58  of  694
# 15 , scoring trunk_id: 59  of  694
# 15 , scoring trunk_id: 60  of  694
# 15 , scoring trunk_id: 61  of  694
# 15 , scoring trunk_id: 62  of  694
# 15 , scoring trunk_id: 63  of  694
# 15 , scoring trunk_id: 64  of  694
# 15 , scoring trunk_id: 65  of  694
# 15 , scoring trunk_id: 66  of  694
# 15 , scoring trunk_id: 67  of  694
# 15 , scoring trunk_id: 68  of  694
# 15 , scoring trunk_id: 69  of  694
# 15 , scoring trunk_id: 70  of  694
# 15 , scoring trunk_id: 71  of  694
# 15 , scoring trunk_id: 72  of  694
# 15 , scoring trunk_id: 73  of  694
# 15 , scoring trunk_id: 74  of  694
# 15 , scoring trunk_id: 75  of  694
# 15 , scoring trunk_id: 76  of  694
# 15 , scoring trunk_id: 77  of  694
# 15 , scoring trunk_id: 78  of  694
# 15 , scoring trunk_id: 79  of  694
# 15 , scoring trunk_id: 80  of  694
# 15 , scoring trunk_id: 81  of  694
# 15 , scoring trunk_id: 82  of  694
# 15 , scoring trunk_id: 83  of  694
# 15 , scoring trunk_id: 84  of  694
# 15 , scoring trunk_id: 85  of  694
# 15 , scoring trunk_id: 86  of  694
# 15 , scoring trunk_id: 87  of  694
# 15 , scoring trunk_id: 88  of  694
# 15 , scoring trunk_id: 89  of  694
# 15 , scoring trunk_id: 90  of  694
# 15 , scoring trunk_id: 91  of  694
# 15 , scoring trunk_id: 92  of  694
# 15 , scoring trunk_id: 93  of  694
# 15 , scoring trunk_id: 94  of  694
# 15 , scoring trunk_id: 95  of  694
# 15 , scoring trunk_id: 96  of  694
# 15 , scoring trunk_id: 97  of  694
# 15 , scoring trunk_id: 98  of  694
# 15 , scoring trunk_id: 110  of  694
# 15 , scoring trunk_id: 111  of  694
# 15 , scoring trunk_id: 112  of  694
# 15 , scoring trunk_id: 113  of  694
# 15 , scoring trunk_id: 114  of  694
# 15 , scoring trunk_id: 115  of  694
# 15 , scoring trunk_id: 116  of  694
# 15 , scoring trunk_id: 117  of  694
# 15 , scoring trunk_id: 118  of  694
# 15 , scoring trunk_id: 119  of  694
# 15 , scoring trunk_id: 120  of  694
# 15 , scoring trunk_id: 121  of  694
# 15 , scoring trunk_id: 122  of  694
# 15 , scoring trunk_id: 123  of  694
# 15 , scoring trunk_id: 124  of  694
# 15 , scoring trunk_id: 125  of  694
# 15 , scoring trunk_id: 126  of  694
# 15 , scoring trunk_id: 127  of  694
# 15 , scoring trunk_id: 128  of  694
# 15 , scoring trunk_id: 129  of  694
# 15 , scoring trunk_id: 130  of  694
# 15 , scoring trunk_id: 131  of  694
# 15 , scoring trunk_id: 132  of  694
# 15 , scoring trunk_id: 133  of  694
# 15 , scoring trunk_id: 134  of  694
# 15 , scoring trunk_id: 135  of  694
# 15 , scoring trunk_id: 136  of  694
# 15 , scoring trunk_id: 137  of  694
# 15 , scoring trunk_id: 138  of  694
# 15 , scoring trunk_id: 139  of  694
# 15 , scoring trunk_id: 140  of  694
# 15 , scoring trunk_id: 141  of  694
# 15 , scoring trunk_id: 142  of  694
# 15 , scoring trunk_id: 143  of  694
# 15 , scoring trunk_id: 144  of  694
# 15 , scoring trunk_id: 145  of  694
# 15 , scoring trunk_id: 146  of  694
# 15 , scoring trunk_id: 147  of  694
# 15 , scoring trunk_id: 148  of  694
# 15 , scoring trunk_id: 149  of  694
# 15 , scoring trunk_id: 150  of  694
# 15 , scoring trunk_id: 151  of  694
# 15 , scoring trunk_id: 152  of  694
# 15 , scoring trunk_id: 153  of  694
# 15 , scoring trunk_id: 154  of  694
# 15 , scoring trunk_id: 155  of  694
# 15 , scoring trunk_id: 156  of  694
# 15 , scoring trunk_id: 157  of  694
# 15 , scoring trunk_id: 158  of  694
# 15 , scoring trunk_id: 159  of  694
# 15 , scoring trunk_id: 160  of  694
# 15 , scoring trunk_id: 161  of  694
# 15 , scoring trunk_id: 162  of  694
# 15 , scoring trunk_id: 163  of  694
# 15 , scoring trunk_id: 164  of  694
# 15 , scoring trunk_id: 165  of  694
# 15 , scoring trunk_id: 166  of  694
# 15 , scoring trunk_id: 167  of  694
# 15 , scoring trunk_id: 168  of  694
# 15 , scoring trunk_id: 169  of  694
# 15 , scoring trunk_id: 170  of  694
# 15 , scoring trunk_id: 171  of  694
# 15 , scoring trunk_id: 172  of  694
# 15 , scoring trunk_id: 173  of  694
# 15 , scoring trunk_id: 174  of  694
# 15 , scoring trunk_id: 175  of  694
# 15 , scoring trunk_id: 176  of  694
# 15 , scoring trunk_id: 177  of  694
# 15 , scoring trunk_id: 178  of  694
# 15 , scoring trunk_id: 179  of  694
# 15 , scoring trunk_id: 180  of  694
# 15 , scoring trunk_id: 181  of  694
# 15 , scoring trunk_id: 182  of  694
# 15 , scoring trunk_id: 183  of  694
# 15 , scoring trunk_id: 184  of  694
# 15 , scoring trunk_id: 185  of  694
# 15 , scoring trunk_id: 186  of  694
# 15 , scoring trunk_id: 187  of  694
# 15 , scoring trunk_id: 188  of  694
# 15 , scoring trunk_id: 189  of  694
# 15 , scoring trunk_id: 190  of  694
# 15 , scoring trunk_id: 191  of  694
# 15 , scoring trunk_id: 192  of  694
# 15 , scoring trunk_id: 193  of  694
# 15 , scoring trunk_id: 194  of  694
# 15 , scoring trunk_id: 195  of  694
# 15 , scoring trunk_id: 196  of  694
# 15 , scoring trunk_id: 197  of  694
# 15 , scoring trunk_id: 198  of  694
# 15 , scoring trunk_id: 199  of  694
# 15 , scoring trunk_id: 200  of  694
# 15 , scoring trunk_id: 201  of  694
# 15 , scoring trunk_id: 202  of  694
# 15 , scoring trunk_id: 203  of  694
# 15 , scoring trunk_id: 204  of  694
# 15 , scoring trunk_id: 205  of  694
# 15 , scoring trunk_id: 206  of  694
# 15 , scoring trunk_id: 207  of  694
# 15 , scoring trunk_id: 208  of  694
# 15 , scoring trunk_id: 209  of  694
# 15 , scoring trunk_id: 210  of  694
# 15 , scoring trunk_id: 211  of  694
# 15 , scoring trunk_id: 212  of  694
# 15 , scoring trunk_id: 213  of  694
# 15 , scoring trunk_id: 214  of  694
# 15 , scoring trunk_id: 215  of  694
# 15 , scoring trunk_id: 216  of  694
# 15 , scoring trunk_id: 217  of  694
# 15 , scoring trunk_id: 218  of  694
# 15 , scoring trunk_id: 219  of  694
# 15 , scoring trunk_id: 220  of  694
# 15 , scoring trunk_id: 221  of  694
# 15 , scoring trunk_id: 222  of  694
# 15 , scoring trunk_id: 223  of  694
# 15 , scoring trunk_id: 224  of  694
# 15 , scoring trunk_id: 225  of  694
# 15 , scoring trunk_id: 226  of  694
# 15 , scoring trunk_id: 227  of  694
# 15 , scoring trunk_id: 228  of  694
# 15 , scoring trunk_id: 229  of  694
# 15 , scoring trunk_id: 230  of  694
# 15 , scoring trunk_id: 231  of  694
# 15 , scoring trunk_id: 232  of  694
# 15 , scoring trunk_id: 233  of  694
# 15 , scoring trunk_id: 234  of  694
# 15 , scoring trunk_id: 235  of  694
# 15 , scoring trunk_id: 236  of  694
# 15 , scoring trunk_id: 237  of  694
# 15 , scoring trunk_id: 238  of  694
# 15 , scoring trunk_id: 239  of  694
# 15 , scoring trunk_id: 240  of  694
# 15 , scoring trunk_id: 241  of  694
# 15 , scoring trunk_id: 242  of  694
# 15 , scoring trunk_id: 243  of  694
# 15 , scoring trunk_id: 244  of  694
# 15 , scoring trunk_id: 245  of  694
# 15 , scoring trunk_id: 246  of  694
# 15 , scoring trunk_id: 247  of  694
# 15 , scoring trunk_id: 248  of  694
# 15 , scoring trunk_id: 249  of  694
# 15 , scoring trunk_id: 250  of  694
# 15 , scoring trunk_id: 251  of  694
# 15 , scoring trunk_id: 252  of  694
# 15 , scoring trunk_id: 253  of  694
# 15 , scoring trunk_id: 254  of  694
# 15 , scoring trunk_id: 255  of  694
# 15 , scoring trunk_id: 256  of  694
# 15 , scoring trunk_id: 257  of  694
# 15 , scoring trunk_id: 258  of  694
# 15 , scoring trunk_id: 259  of  694
# 15 , scoring trunk_id: 260  of  694
# 15 , scoring trunk_id: 261  of  694
# 15 , scoring trunk_id: 262  of  694
# 15 , scoring trunk_id: 263  of  694
# 15 , scoring trunk_id: 264  of  694
# 15 , scoring trunk_id: 265  of  694
# 15 , scoring trunk_id: 266  of  694
# 15 , scoring trunk_id: 267  of  694
# 15 , scoring trunk_id: 268  of  694
# 15 , scoring trunk_id: 269  of  694
# 15 , scoring trunk_id: 270  of  694
# 15 , scoring trunk_id: 271  of  694
# 15 , scoring trunk_id: 272  of  694
# 15 , scoring trunk_id: 273  of  694
# 15 , scoring trunk_id: 274  of  694
# 15 , scoring trunk_id: 275  of  694
# 15 , scoring trunk_id: 276  of  694
# 15 , scoring trunk_id: 277  of  694
# 15 , scoring trunk_id: 278  of  694
# 15 , scoring trunk_id: 279  of  694
# 15 , scoring trunk_id: 280  of  694
# 15 , scoring trunk_id: 281  of  694
# 15 , scoring trunk_id: 282  of  694
# 15 , scoring trunk_id: 283  of  694
# 15 , scoring trunk_id: 284  of  694
# 15 , scoring trunk_id: 285  of  694
# 15 , scoring trunk_id: 286  of  694
# 15 , scoring trunk_id: 287  of  694
# 15 , scoring trunk_id: 288  of  694
# 15 , scoring trunk_id: 289  of  694
# 15 , scoring trunk_id: 290  of  694
# 15 , scoring trunk_id: 291  of  694
# 15 , scoring trunk_id: 292  of  694
# 15 , scoring trunk_id: 293  of  694
# 15 , scoring trunk_id: 294  of  694
# 15 , scoring trunk_id: 295  of  694
# 15 , scoring trunk_id: 296  of  694
# 15 , scoring trunk_id: 297  of  694
# 15 , scoring trunk_id: 298  of  694
# 15 , scoring trunk_id: 299  of  694
# 15 , scoring trunk_id: 300  of  694
# 15 , scoring trunk_id: 301  of  694
# 15 , scoring trunk_id: 302  of  694
# 15 , scoring trunk_id: 303  of  694
# 15 , scoring trunk_id: 304  of  694
# 15 , scoring trunk_id: 305  of  694
# 15 , scoring trunk_id: 306  of  694
# 15 , scoring trunk_id: 307  of  694
# 15 , scoring trunk_id: 308  of  694
# 15 , scoring trunk_id: 309  of  694
# 15 , scoring trunk_id: 310  of  694
# 15 , scoring trunk_id: 311  of  694
# 15 , scoring trunk_id: 312  of  694
# 15 , scoring trunk_id: 313  of  694
# 15 , scoring trunk_id: 314  of  694
# 15 , scoring trunk_id: 315  of  694
# 15 , scoring trunk_id: 316  of  694
# 15 , scoring trunk_id: 317  of  694
# 15 , scoring trunk_id: 318  of  694
# 15 , scoring trunk_id: 319  of  694
# 15 , scoring trunk_id: 320  of  694
# 15 , scoring trunk_id: 321  of  694
# 15 , scoring trunk_id: 322  of  694
# 15 , scoring trunk_id: 323  of  694
# 15 , scoring trunk_id: 324  of  694
# 15 , scoring trunk_id: 325  of  694
# 15 , scoring trunk_id: 326  of  694
# 15 , scoring trunk_id: 327  of  694
# 15 , scoring trunk_id: 328  of  694
# 15 , scoring trunk_id: 329  of  694
# 15 , scoring trunk_id: 330  of  694
# 15 , scoring trunk_id: 331  of  694
# 15 , scoring trunk_id: 332  of  694
# 15 , scoring trunk_id: 333  of  694
# 15 , scoring trunk_id: 334  of  694
# 15 , scoring trunk_id: 335  of  694
# 15 , scoring trunk_id: 336  of  694
# 15 , scoring trunk_id: 337  of  694
# 15 , scoring trunk_id: 338  of  694
# 15 , scoring trunk_id: 339  of  694
# 15 , scoring trunk_id: 340  of  694
# 15 , scoring trunk_id: 341  of  694
# 15 , scoring trunk_id: 342  of  694
# 15 , scoring trunk_id: 343  of  694
# 15 , scoring trunk_id: 344  of  694
# 15 , scoring trunk_id: 345  of  694
# 15 , scoring trunk_id: 346  of  694
# 15 , scoring trunk_id: 347  of  694
# 15 , scoring trunk_id: 348  of  694
# 15 , scoring trunk_id: 349  of  694
# 15 , scoring trunk_id: 350  of  694
# 15 , scoring trunk_id: 351  of  694
# 15 , scoring trunk_id: 352  of  694
# 15 , scoring trunk_id: 353  of  694
# 15 , scoring trunk_id: 354  of  694
# 15 , scoring trunk_id: 355  of  694
# 15 , scoring trunk_id: 356  of  694
# 15 , scoring trunk_id: 357  of  694
# 15 , scoring trunk_id: 358  of  694
# 15 , scoring trunk_id: 359  of  694
# 15 , scoring trunk_id: 360  of  694
# 15 , scoring trunk_id: 361  of  694
# 15 , scoring trunk_id: 362  of  694
# 15 , scoring trunk_id: 363  of  694
# 15 , scoring trunk_id: 364  of  694
# 15 , scoring trunk_id: 365  of  694
# 15 , scoring trunk_id: 366  of  694
# 15 , scoring trunk_id: 367  of  694
# 15 , scoring trunk_id: 368  of  694
# 15 , scoring trunk_id: 369  of  694
# 15 , scoring trunk_id: 370  of  694
# 15 , scoring trunk_id: 371  of  694
# 15 , scoring trunk_id: 372  of  694
# 15 , scoring trunk_id: 373  of  694
# 15 , scoring trunk_id: 374  of  694
# 15 , scoring trunk_id: 375  of  694
# 15 , scoring trunk_id: 376  of  694
# 15 , scoring trunk_id: 377  of  694
# 15 , scoring trunk_id: 378  of  694
# 15 , scoring trunk_id: 379  of  694
# 15 , scoring trunk_id: 380  of  694
# 15 , scoring trunk_id: 381  of  694
# 15 , scoring trunk_id: 382  of  694
# 15 , scoring trunk_id: 383  of  694
# 15 , scoring trunk_id: 384  of  694
# 15 , scoring trunk_id: 385  of  694
# 15 , scoring trunk_id: 386  of  694
# 15 , scoring trunk_id: 387  of  694
# 15 , scoring trunk_id: 388  of  694
# 15 , scoring trunk_id: 389  of  694
# 15 , scoring trunk_id: 390  of  694
# 15 , scoring trunk_id: 391  of  694
# 15 , scoring trunk_id: 392  of  694
# 15 , scoring trunk_id: 393  of  694
# 15 , scoring trunk_id: 394  of  694
# 15 , scoring trunk_id: 395  of  694
# 15 , scoring trunk_id: 396  of  694
# 15 , scoring trunk_id: 397  of  694
# 15 , scoring trunk_id: 398  of  694
# 15 , scoring trunk_id: 399  of  694
# 15 , scoring trunk_id: 400  of  694
# 15 , scoring trunk_id: 401  of  694
# 15 , scoring trunk_id: 402  of  694
# 15 , scoring trunk_id: 403  of  694
# 15 , scoring trunk_id: 404  of  694
# 15 , scoring trunk_id: 405  of  694
# 15 , scoring trunk_id: 406  of  694
# 15 , scoring trunk_id: 407  of  694
# 15 , scoring trunk_id: 408  of  694
# 15 , scoring trunk_id: 409  of  694
# 15 , scoring trunk_id: 410  of  694
# 15 , scoring trunk_id: 411  of  694
# 15 , scoring trunk_id: 412  of  694
# 15 , scoring trunk_id: 413  of  694
# 15 , scoring trunk_id: 414  of  694
# 15 , scoring trunk_id: 415  of  694
# 15 , scoring trunk_id: 416  of  694
# 15 , scoring trunk_id: 417  of  694
# 15 , scoring trunk_id: 418  of  694
# 15 , scoring trunk_id: 419  of  694
# 15 , scoring trunk_id: 420  of  694
# 15 , scoring trunk_id: 421  of  694
# 15 , scoring trunk_id: 422  of  694
# 15 , scoring trunk_id: 423  of  694
# 15 , scoring trunk_id: 424  of  694
# 15 , scoring trunk_id: 425  of  694
# 15 , scoring trunk_id: 426  of  694
# 15 , scoring trunk_id: 427  of  694
# 15 , scoring trunk_id: 428  of  694
# 15 , scoring trunk_id: 429  of  694
# 15 , scoring trunk_id: 430  of  694
# 15 , scoring trunk_id: 431  of  694
# 15 , scoring trunk_id: 432  of  694
# 15 , scoring trunk_id: 433  of  694
# 15 , scoring trunk_id: 434  of  694
# 15 , scoring trunk_id: 435  of  694
# 15 , scoring trunk_id: 436  of  694
# 15 , scoring trunk_id: 437  of  694
# 15 , scoring trunk_id: 438  of  694
# 15 , scoring trunk_id: 439  of  694
# 15 , scoring trunk_id: 440  of  694
# 15 , scoring trunk_id: 441  of  694
# 15 , scoring trunk_id: 442  of  694
# 15 , scoring trunk_id: 443  of  694
# 15 , scoring trunk_id: 444  of  694
# 15 , scoring trunk_id: 445  of  694
# 15 , scoring trunk_id: 446  of  694
# 15 , scoring trunk_id: 447  of  694
# 15 , scoring trunk_id: 448  of  694
# 15 , scoring trunk_id: 449  of  694
# 15 , scoring trunk_id: 450  of  694
# 15 , scoring trunk_id: 451  of  694
# 15 , scoring trunk_id: 452  of  694
# 15 , scoring trunk_id: 453  of  694
# 15 , scoring trunk_id: 454  of  694
# 15 , scoring trunk_id: 455  of  694
# 15 , scoring trunk_id: 456  of  694
# 15 , scoring trunk_id: 457  of  694
# 15 , scoring trunk_id: 458  of  694
# 15 , scoring trunk_id: 459  of  694
# 15 , scoring trunk_id: 460  of  694
# 15 , scoring trunk_id: 461  of  694
# 15 , scoring trunk_id: 462  of  694
# 15 , scoring trunk_id: 463  of  694
# 15 , scoring trunk_id: 464  of  694
# 15 , scoring trunk_id: 465  of  694
# 15 , scoring trunk_id: 466  of  694
# 15 , scoring trunk_id: 467  of  694
# 15 , scoring trunk_id: 468  of  694
# 15 , scoring trunk_id: 469  of  694
# 15 , scoring trunk_id: 470  of  694
# 15 , scoring trunk_id: 471  of  694
# 15 , scoring trunk_id: 472  of  694
# 15 , scoring trunk_id: 473  of  694
# 15 , scoring trunk_id: 474  of  694
# 15 , scoring trunk_id: 475  of  694
# 15 , scoring trunk_id: 476  of  694
# 15 , scoring trunk_id: 477  of  694
# 15 , scoring trunk_id: 478  of  694
# 15 , scoring trunk_id: 479  of  694
# 15 , scoring trunk_id: 480  of  694
# 15 , scoring trunk_id: 481  of  694
# 15 , scoring trunk_id: 482  of  694
# 15 , scoring trunk_id: 483  of  694
# 15 , scoring trunk_id: 484  of  694
# 15 , scoring trunk_id: 485  of  694
# 15 , scoring trunk_id: 486  of  694
# 15 , scoring trunk_id: 487  of  694
# 15 , scoring trunk_id: 488  of  694
# 15 , scoring trunk_id: 489  of  694
# 15 , scoring trunk_id: 490  of  694
# 15 , scoring trunk_id: 491  of  694
# 15 , scoring trunk_id: 492  of  694
# 15 , scoring trunk_id: 493  of  694
# 15 , scoring trunk_id: 494  of  694
# 15 , scoring trunk_id: 495  of  694
# 15 , scoring trunk_id: 496  of  694
# 15 , scoring trunk_id: 497  of  694
# 15 , scoring trunk_id: 498  of  694
